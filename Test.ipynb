# %%
import pandas as pd

# %%
data = pd.read_csv("Demo_Data.csv", sep = '\t', encoding = 'unicode_escape')

# %%
data.head()
# Out:
#   AccountNumber  Volume ExceptionCode IntIndicator OriginCity OriginState  \
# 0    724Demo000       1             0     DOMESTIC  UNDEFINED   UNDEFINED
# 1    78VDemo000       4             0     DOMESTIC  STRATFORD          CT
# 2    6W82Demo00       1             0     DOMESTIC   SOMERSET          NJ
# 3    2R53Demo00       3             0     DOMESTIC     CARSON          CA
# 4    9993Demo00       1           2Y      DOMESTIC     MAUMEE          OH
#
#   OriginCountry ServiceCode ServiceName       TopService ServiceLevelMode  \
# 0     UNDEFINED         A30  UPS GROUND  GROUND/STANDARD           GROUND
# 1            US         A30  UPS GROUND  GROUND/STANDARD           GROUND
# 2            US         A30  UPS GROUND  GROUND/STANDARD           GROUND
# 3            US         A30  UPS GROUND  GROUND/STANDARD           GROUND
# 4            US         A30  UPS GROUND  GROUND/STANDARD           GROUND
#
#      Year  Month   Day      AccountName PerformStatusNetDetail  \
# ...

# %%
data['PerformStatusNetDetail'].unique()
# Out:
# array(['ONTIME', 'EARLY', 'LATE BY TIME', 'UNMEASURED', 'LATE BY DAY'],
#       dtype=object)

# %%
data['AccountNumber'].unique()
# Out:
# array(['724Demo000', '78VDemo000', '6W82Demo00', ..., '06Y39YDemo',
#        '9302AYDemo', '2938AYDemo'], dtype=object)

# %%
data.tail()
# Out:
#        AccountNumber  Volume ExceptionCode IntIndicator OriginCity  \
# 338550    5609YYDemo       4             0     DOMESTIC   PORTLAND
# 338551    5609YYDemo       3             0     DOMESTIC   PORTLAND
# 338552    5609YYDemo       5             0     DOMESTIC   PORTLAND
# 338553    5609YYDemo       9             0     DOMESTIC   PORTLAND
# 338554    5609YYDemo       1             0     DOMESTIC   PORTLAND
#
#        OriginState OriginCountry ServiceCode ServiceName       TopService  \
# 338550          OR            US         A30  UPS GROUND  GROUND/STANDARD
# 338551          OR            US         A30  UPS GROUND  GROUND/STANDARD
# 338552          OR            US         A30  UPS GROUND  GROUND/STANDARD
# 338553          OR            US         A30  UPS GROUND  GROUND/STANDARD
# 338554          OR            US         A30  UPS GROUND  GROUND/STANDARD
#
#        ServiceLevelMode    Year  Month   Day      AccountName  \
# ...

# %%
data.describe()
# Out:
#               Volume           Year          Month            Day
# count  338555.000000  336166.000000  336166.000000  336166.000000
# mean        2.429215    2018.746298       5.951512      15.729521
# std         4.237459       0.714202       3.446435       8.638191
# min         1.000000    2017.000000       1.000000       1.000000
# 25%         1.000000    2018.000000       3.000000       8.000000
# 50%         1.000000    2019.000000       5.000000      16.000000
# 75%         2.000000    2019.000000       9.000000      23.000000
# max       467.000000    2020.000000      12.000000      31.000000

# %%
# Out:
#         AccountNumber  Volume  ExceptionCode  IntIndicator  OriginCity  \
# 0               False   False          False         False       False
# 1               False   False          False         False       False
# 2               False   False          False         False       False
# 3               False   False          False         False       False
# 4               False   False          False         False       False
# 5               False   False          False         False       False
# 6               False   False          False         False       False
# 7               False   False          False         False       False
# 8               False   False          False         False       False
# 9               False   False          False         False       False
# 10              False   False          False         False       False
# 11              False   False          False         False       False
# ...
